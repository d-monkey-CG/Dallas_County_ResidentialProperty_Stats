# %% [markdown]
# <a href="https://colab.research.google.com/github/d-monkey-CG/Dallas_County_ResidentialProperty_Stats/blob/main/Hud_Crosswalk_20to24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import each hud crosswalk file and add a year column

df_20 = pd.read_excel('/content/drive/MyDrive/HUD_Crosswalk/ZIP_TRACT_122020.xlsx')

df_20['Year'] = 2020

df_21 = pd.read_excel('/content/drive/MyDrive/HUD_Crosswalk/ZIP_TRACT_122021.xlsx')

df_21['Year'] = 2021

df_22 = pd.read_excel('/content/drive/MyDrive/HUD_Crosswalk/ZIP_TRACT_122022.xlsx')

df_22['Year'] = 2022

df_23 = pd.read_excel('/content/drive/MyDrive/HUD_Crosswalk/ZIP_TRACT_122023.xlsx')

df_23['Year'] = 2023

df_24 = pd.read_excel('/content/drive/MyDrive/HUD_Crosswalk/ZIP_TRACT_122024.xlsx')

df_24['Year'] = 2024

df_hud = pd.concat([df_20, df_21, df_22, df_23, df_24], ignore_index=True)

df_hud.info()
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894499 entries, 0 to 894498
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ZIP                  722322 non-null  float64
#  1   TRACT                722322 non-null  float64
#  2   RES_RATIO            722322 non-null  float64
#  3   BUS_RATIO            722322 non-null  float64
#  4   OTH_RATIO            722322 non-null  float64
#  5   TOT_RATIO            722322 non-null  float64
#  6   Year                 894499 non-null  int64
#  7   zip                  172177 non-null  float64
#  8   tract                172177 non-null  float64
#  9   usps_zip_pref_city   172177 non-null  object
# ...

# %%
df_hud.to_csv('hud_crosswalk_20to24.csv')
